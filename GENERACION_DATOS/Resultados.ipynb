# %% [markdown]
# # Generación de Datos Simulados
# Se busca simular la trayectoria de un alumno, a partir de ciertos datos dados

# %%
# Datos del Alumno
matriculaAlumno = 2021101021
situacion = 0
carrera = 3
idTiempoI = 19
idTiempo = 0
matriculaProfesor = 0
idMateria = 0
idNivel = 0
idTiempo = 0
empleoAlumno = 0
empleoProfesor = 0
calificacionMateriaAlumno = 0
categoriaEvaluacionProfesor = 0

# %%
# Datos del Profesor
Profesor = []
Profesor.append([1990096567, 0])
Profesor.append([1984096568, 1])
Profesor.append([1996096569, 0])
Profesor.append([1999096570, 1])
Profesor.append([1987096571, 0])
Profesor.append([1992096572, 1])
Profesor.append([1988096573, 0])
Profesor.append([2002096574, 1])
Profesor.append([2000096575, 0])
Profesor.append([2005096576, 0])
Profesor.append([2005096577, 1])
Profesor.append([2003096578, 0])
Profesor.append([1999096579, 0])
Profesor.append([1997096580, 1])
Profesor.append([2000096581, 0])
Profesor.append([2003096582, 0])
Profesor.append([2003096583, 1])
Profesor.append([1997096584, 0])
Profesor.append([2000096585, 1])
Profesor.append([2003096586, 1])

# %%
# Datos de la Materia
Materia = []
profesores1 = [Profesor[19][0], Profesor[18][0], Profesor[17][0]]
profesores2 = [Profesor[16][0], Profesor[15][0], Profesor[14][0]]
profesores3 = [Profesor[13][0], Profesor[12][0], Profesor[11][0]]
profesores4 = [Profesor[10][0], Profesor[9][0], Profesor[8][0]]
profesores5 = [Profesor[7][0], Profesor[6][0], Profesor[5][0]]
profesores6 = [Profesor[4][0], Profesor[3][0], Profesor[2][0], Profesor[1][0], Profesor[0][0]]
for i in range(1001, 1010):
    Materia.append([i, profesores1])
    
for i in range(2001, 2010):
    Materia.append([i, profesores2])
    
for i in range(3001, 3031):
    Materia.append([i, profesores3])
    
for i in range(4001, 4019):
    Materia.append([i, profesores4])
    
for i in range(5001, 5029):
    Materia.append([i, profesores5])
    
for i in range(6001, 6028):
    Materia.append([i, profesores6])

# %%
# Datos del Nivel Escolar
Nivel = []
t1 = [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009]
t2 = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]
p3 = [3001, 3002, 3003, 3004, 3005, 3006, 3007, 3008, 3009, 3010]
p4 = [4001, 4002, 4003, 4004, 4005, 4006, 4007, 4008, 4009, 4010]
p5 = [5001, 5002, 5003, 5004, 5005, 5006, 5007, 5008, 5009, 5010]
p6 = [6001, 6002, 6003, 6004, 6005, 6006, 6007, 6008, 6009, 6010]
s3 = [3011, 3012, 3013, 3014, 3015, 3016, 3017, 3018, 3019, 3020]
s4 = [4011, 4012, 4013, 4014, 4015, 4016, 4017, 4018, 4019]
s5 = [5011, 5012, 5013, 5014, 5015, 5016, 5017, 5018, 5019]
s6 = [6011, 6012, 6013, 6014, 6015, 6016, 6017, 6018, 6019]
m3 = [3021, 3022, 3023, 3024, 3025, 3026, 3027, 3028, 3029, 3030]
m4 = [4021, 4022, 4023, 4024, 4025, 4026, 4027, 4028]
m5 = [5021, 5022, 5023, 5024, 5025, 5026, 5027, 5028]
m6 = [6021, 6022, 6023, 6024, 6025, 6026, 6027, 6028]
Nivel.append([101, t1])
Nivel.append([102, t2])
Nivel.append([203, p3])
Nivel.append([204, p4])
Nivel.append([205, p5])
Nivel.append([206, p6])
Nivel.append([303, m3])
Nivel.append([304, m4])
Nivel.append([305, m5])
Nivel.append([306, m6])
Nivel.append([403, s3])
Nivel.append([404, s4])
Nivel.append([405, s5])
Nivel.append([406, s6])

# %%
# Importamos las Bibliotecas necesarias
import random

# %%
# Generación de los datos
res = []
niveles = []
niveles.append(Nivel[0])
niveles.append(Nivel[1])
if carrera == 1:
    for i in range(2, 6):
        niveles.append(Nivel[i])
elif carrera == 2:
    for i in range(6, 10):
        niveles.append(Nivel[i])
else:
    for i in range(10, 14):
        niveles.append(Nivel[i])
        
semestreEmpleo = random.randint(4, 6)
semestreSalta = random.randint(1, 5)
for niv in niveles:
    if situacion == 0:
        empleoAlumno = 0
        for ayuda in niv[1]:
            for mat in Materia:
                if ayuda == mat[0]:
                    matriculaProfesor = random.choice(mat[1])
            for prof in Profesor:
                if matriculaProfesor == prof[0]:
                    empleoProfesor = prof[1]
            idTiempo = idTiempoI
            for i in range(0, 3):
                if empleoProfesor == 0:
                    categoriaEvaluacionProfesor = random.randint(1, 4)
                else:
                    categoriaEvaluacionProfesor = random.randint(1, 2)
                calificacionMateriaAlumno = random.randint(6, 10)
                res.append([matriculaAlumno,
                          matriculaProfesor,
                          ayuda,
                          niv[0],
                          idTiempo,
                          empleoAlumno,
                          empleoProfesor, 
                          calificacionMateriaAlumno,
                          categoriaEvaluacionProfesor])
                idTiempo += 1
    elif situacion == 1:
        for ayuda in niv[1]:
            for mat in Materia:
                if ayuda == mat[0]:
                    matriculaProfesor = random.choice(mat[1])
            for prof in Profesor:
                if matriculaProfesor == prof[0]:
                    empleoProfesor = prof[1]
            idTiempo = idTiempoI
            for i in range(0, 3):
                if niv[0] % 10 >= semestreEmpleo:
                    empleoAlumno = 1
                if empleoProfesor == 0:
                    categoriaEvaluacionProfesor = random.randint(1, 4)
                else:
                    categoriaEvaluacionProfesor = random.randint(1, 2)
                if empleoAlumno == 1:
                    calificacionMateriaAlumno = random.randint(5, 9)
                elif empleoAlumno == 0:
                    calificacionMateriaAlumno = random.randint(6, 10)
                res.append([matriculaAlumno,
                          matriculaProfesor,
                          ayuda,
                          niv[0],
                          idTiempo,
                          empleoAlumno,
                          empleoProfesor, 
                          calificacionMateriaAlumno,
                          categoriaEvaluacionProfesor])
                idTiempo += 1
    elif situacion == 2:
        bandera = 0
        if (niv[0] - semestreSalta) % 10 == 0:
            materiaSelec = random.choice(niv[1])
            print(materiaSelec)
            bandera = 1
        for ayuda in niv[1]:
            for mat in Materia:
                if ayuda == mat[0]:
                    matriculaProfesor = random.choice(mat[1])
            for prof in Profesor:
                if matriculaProfesor == prof[0]:
                    empleoProfesor = prof[1]
            idTiempo = idTiempoI
            for i in range(0, 3):    
                if empleoProfesor == 0:
                    categoriaEvaluacionProfesor = random.randint(1, 4)
                else:
                    categoriaEvaluacionProfesor = random.randint(1, 2)
                if empleoAlumno == 0:
                    calificacionMateriaAlumno = random.randint(6, 10)
                if bandera == 1:
                    if materiaSelec == ayuda:
                        idTiempo += 3
                        bandera = 0
                res.append([matriculaAlumno,
                          matriculaProfesor,
                          ayuda,
                          niv[0],
                          idTiempo,
                          empleoAlumno,
                          empleoProfesor, 
                          calificacionMateriaAlumno,
                          categoriaEvaluacionProfesor])
                idTiempo += 1
    idTiempoI += 3

# %%
# Datos obtenidos
for r in res:
    print(r)
    
print(len(res))
# Out:
# [2021101021, 1997096584, 1001, 101, 19, 0, 0, 6, 1]
# [2021101021, 1997096584, 1001, 101, 20, 0, 0, 8, 4]
# [2021101021, 1997096584, 1001, 101, 21, 0, 0, 7, 2]
# [2021101021, 2000096585, 1002, 101, 19, 0, 1, 10, 2]
# [2021101021, 2000096585, 1002, 101, 20, 0, 1, 10, 2]
# [2021101021, 2000096585, 1002, 101, 21, 0, 1, 10, 1]
# [2021101021, 2000096585, 1003, 101, 19, 0, 1, 9, 2]
# [2021101021, 2000096585, 1003, 101, 20, 0, 1, 6, 1]
# [2021101021, 2000096585, 1003, 101, 21, 0, 1, 9, 2]
# [2021101021, 2003096586, 1004, 101, 19, 0, 1, 10, 1]
# [2021101021, 2003096586, 1004, 101, 20, 0, 1, 10, 2]
# [2021101021, 2003096586, 1004, 101, 21, 0, 1, 10, 1]
# [2021101021, 1997096584, 1005, 101, 19, 0, 0, 9, 4]
# [2021101021, 1997096584, 1005, 101, 20, 0, 0, 6, 3]
# [2021101021, 1997096584, 1005, 101, 21, 0, 0, 8, 2]
# [2021101021, 1997096584, 1006, 101, 19, 0, 0, 8, 1]
# [2021101021, 1997096584, 1006, 101, 20, 0, 0, 6, 2]
# [2021101021, 1997096584, 1006, 101, 21, 0, 0, 8, 2]
# ...
